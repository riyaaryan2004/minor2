# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/fitbit_final_dataset.csv")
df.head()
# Out:
#            Id        date  TotalSteps  Calories  VeryActiveMinutes  \
# 0  1503960366  2016-04-12       13162      1985                 25
# 1  1503960366  2016-04-13       10735      1797                 21
# 2  1503960366  2016-04-14       10460      1776                 30
# 3  1503960366  2016-04-15        9762      1745                 29
# 4  1503960366  2016-04-16       12669      1863                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# 0                   13                   328               728
# 1                   19                   217               776
# 2                   11                   181              1218
# 3                   34                   209               726
# 4                   10                   221               773
#
#    TotalIntensity    avg_hr      max_hr     min_hr     hr_std  \
# 0       17.875000  78.99772  138.764092  52.987474  15.247663
# 1       13.250000  78.99772  138.764092  52.987474  15.247663
# 2       12.208333  78.99772  138.764092  52.987474  15.247663
# 3       15.166667  78.99772  138.764092  52.987474  15.247663
# 4       14.541667  78.99772  138.764092  52.987474  15.247663
#
#    TotalMinutesAsleep  TotalTimeInBed  sleep_hours  sleep_efficiency  \
# 0          327.000000      346.000000     5.450000          0.945087
# 1          384.000000      407.000000     6.400000          0.943489
# 2          420.155294      459.331765     7.002588          0.916778
# 3          412.000000      442.000000     6.866667          0.932127
# 4          340.000000      367.000000     5.666667          0.926431
#
#    mood_score  productivity_score
# 0    6.200142            5.143750
# 1    6.068392            5.544444
# 2    6.300936            5.212082
# 3    6.058475            7.066667
# 4    6.185225            5.606944

# %%
df.shape
# Out:
# (1400, 19)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    1400 non-null   int64
#  1   date                  1400 non-null   str
#  2   TotalSteps            1400 non-null   int64
#  3   Calories              1400 non-null   int64
#  4   VeryActiveMinutes     1400 non-null   int64
#  5   FairlyActiveMinutes   1400 non-null   int64
#  6   LightlyActiveMinutes  1400 non-null   int64
#  7   SedentaryMinutes      1400 non-null   int64
#  8   TotalIntensity        1400 non-null   float64
#  9   avg_hr                1400 non-null   float64
#  10  max_hr                1400 non-null   float64
#  11  min_hr                1400 non-null   float64
#  12  hr_std                1400 non-null   float64
#  13  TotalMinutesAsleep    1400 non-null   float64
#  14  TotalTimeInBed        1400 non-null   float64
#  15  sleep_hours           1400 non-null   float64
#  16  sleep_efficiency      1400 non-null   float64
#  17  mood_score            1400 non-null   float64
#  18  productivity_score    1400 non-null   float64
# dtypes: float64(11), int64(7), str(1)
# memory usage: 207.9 KB

# %%
df.describe()
# Out:
#                  Id    TotalSteps     Calories  VeryActiveMinutes  \
# count  1.400000e+03   1400.000000  1400.000000        1400.000000
# mean   4.783443e+09   7291.280714  2268.971429          19.732857
# std    2.383699e+09   5214.348802   754.768790          31.751741
# min    1.503960e+09      0.000000     0.000000           0.000000
# 25%    2.320127e+09   3146.750000  1799.000000           0.000000
# 50%    4.445115e+09   7012.500000  2115.000000           2.000000
# 75%    6.962181e+09  10565.250000  2772.750000          30.000000
# max    8.877689e+09  36019.000000  4900.000000         210.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count          1400.000000           1400.000000       1400.000000
# mean             13.446429            185.532143        991.962143
# std              26.396249            114.144481        313.271576
# min               0.000000              0.000000          0.000000
# 25%               0.000000            111.000000        728.750000
# 50%               6.000000            195.000000       1057.000000
# 75%              18.000000            262.000000       1244.000000
# max             660.000000            720.000000       1440.000000
#
#        TotalIntensity       avg_hr       max_hr       min_hr       hr_std  \
# count     1400.000000  1400.000000  1400.000000  1400.000000  1400.000000
# mean        11.714374    78.997720   138.764092    52.987474    15.247663
# std          6.913714     6.106241    12.590100     4.212878     3.728916
# min          0.000000    56.751144    80.000000    36.000000     3.486183
# 25%          6.682292    78.997720   138.764092    52.987474    15.247663
# 50%         12.020833    78.997720   138.764092    52.987474    15.247663
# 75%         16.503571    78.997720   138.764092    52.987474    15.247663
# max         37.666667   109.823317   203.000000    71.000000    43.709249
#
#        TotalMinutesAsleep  TotalTimeInBed  sleep_hours  sleep_efficiency  \
# count         1400.000000     1400.000000  1400.000000       1400.000000
# mean           420.155294      459.331765     7.002588          0.916778
# std             65.177712       69.741400     1.086295          0.048165
# min             58.000000       61.000000     0.966667          0.498361
# 25%            420.155294      459.331765     7.002588          0.916778
# 50%            420.155294      459.331765     7.002588          0.916778
# 75%            420.155294      459.331765     7.002588          0.916778
# max            796.000000      961.000000    13.266667          1.000000
#
#         mood_score  productivity_score
# count  1400.000000         1400.000000
# mean      5.513796            4.973634
# std       1.345253            2.209544
# min       1.276848            0.611806
# 25%       4.472183            3.043679
# 50%       5.479184            4.397360
# 75%       6.419446            6.426075
# max      10.000000           10.000000

# %%
df.isnull().sum()
# Out:
# Id                      0
# date                    0
# TotalSteps              0
# Calories                0
# VeryActiveMinutes       0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# TotalIntensity          0
# avg_hr                  0
# max_hr                  0
# min_hr                  0
# hr_std                  0
# TotalMinutesAsleep      0
# TotalTimeInBed          0
# sleep_hours             0
# sleep_efficiency        0
# mood_score              0
# productivity_score      0
# dtype: int64

# %% [markdown]
# The dataset was checked for missing values.
# All columns show 0 missing values, indicating that the preprocessing step successfully handled missing data using mean imputation.

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["mood_score"], bins=20)
plt.title("Mood Score Distribution")
plt.show()

# %% [markdown]
# The histogram shows the distribution of mood scores across the dataset.
# Most mood values fall between 4 and 7, indicating that moderate mood levels are the most common.
# Very low or very high mood values occur less frequently.

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["productivity_score"], bins=20)
plt.title("Productivity Score Distribution")
plt.show()

# %% [markdown]
# The histogram shows the distribution of productivity scores across the dataset.
# Most productivity values fall between 3 and 6, indicating moderate productivity
# levels for most days. Extremely low or extremely high productivity values occur
# less frequently.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm")
plt.title("Feature Correlation")
plt.show()

# %%
features = [
    "TotalSteps",
    "VeryActiveMinutes",
    "FairlyActiveMinutes",
    "LightlyActiveMinutes",
    "SedentaryMinutes",
    "TotalIntensity",
    "sleep_hours",
    "sleep_efficiency",
    "avg_hr",
    "hr_std"
]

X = df[features]

y_mood = df["mood_score"]
y_prod = df["productivity_score"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y_mood, test_size=0.2, random_state=42
)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 0.049840995544654286
# RMSE: 0.10317229661421358

# %%
importance = pd.Series(model.feature_importances_, index=features)

importance.sort_values().plot(kind="barh")
plt.title("Feature Importance")
plt.show()
