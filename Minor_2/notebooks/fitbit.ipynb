# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/fitbit_final_dataset.csv")
df.head()
# Out:
#            Id        date  TotalSteps  Calories  VeryActiveMinutes  \
# 0  1503960366  2016-04-12       13162      1985                 25
# 1  1503960366  2016-04-13       10735      1797                 21
# 2  1503960366  2016-04-14       10460      1776                 30
# 3  1503960366  2016-04-15        9762      1745                 29
# 4  1503960366  2016-04-16       12669      1863                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# 0                   13                   328               728
# 1                   19                   217               776
# 2                   11                   181              1218
# 3                   34                   209               726
# 4                   10                   221               773
#
#    TotalIntensity     avg_hr  max_hr  min_hr     hr_std  hr_range  \
# 0           429.0  78.633232   135.0    53.0  13.665153      83.0
# ...

# %%
df.shape
# Out:
# (1240, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    1240 non-null   int64
#  1   date                  1240 non-null   str
#  2   TotalSteps            1240 non-null   int64
#  3   Calories              1240 non-null   int64
#  4   VeryActiveMinutes     1240 non-null   int64
#  5   FairlyActiveMinutes   1240 non-null   int64
#  6   LightlyActiveMinutes  1240 non-null   int64
#  7   SedentaryMinutes      1240 non-null   int64
#  8   TotalIntensity        1240 non-null   float64
#  9   avg_hr                1240 non-null   float64
#  10  max_hr                1240 non-null   float64
#  11  min_hr                1240 non-null   float64
#  12  hr_std                1240 non-null   float64
#  13  hr_range              1240 non-null   float64
#  14  TotalMinutesAsleep    410 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  Id    TotalSteps     Calories  VeryActiveMinutes  \
# count  1.240000e+03   1240.000000  1240.000000        1240.000000
# mean   4.776347e+09   8168.658065  2361.212097          21.933065
# std    2.398752e+09   4842.744015   708.185094          32.788257
# min    1.503960e+09      4.000000    52.000000           0.000000
# 25%    2.320127e+09   4568.750000  1858.250000           0.000000
# 50%    4.445115e+09   7798.500000  2217.500000           5.000000
# 75%    6.962181e+09  11034.750000  2830.500000          33.000000
# max    8.877689e+09  36019.000000  4900.000000         210.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count          1240.000000           1240.000000       1240.000000
# mean             14.530645            208.270968        960.793548
# std              20.606323             99.791085        281.587924
# min               0.000000              0.000000          0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Id                        0
# date                      0
# TotalSteps                0
# Calories                  0
# VeryActiveMinutes         0
# FairlyActiveMinutes       0
# LightlyActiveMinutes      0
# SedentaryMinutes          0
# TotalIntensity            0
# avg_hr                    0
# max_hr                    0
# min_hr                    0
# hr_std                    0
# hr_range                  0
# TotalMinutesAsleep      830
# TotalTimeInBed          830
# sleep_hours               0
# sleep_efficiency          0
# mood_score                0
# productivity_score        0
# dtype: int64

# %% [markdown]
# The dataset was checked for missing values.
# All columns show 0 missing values, indicating that the preprocessing step successfully handled missing data using mean imputation.

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["mood_score"], bins=20)
plt.title("Mood Score Distribution")
plt.show()

# %% [markdown]
# The histogram shows the distribution of mood scores across the dataset.
# Most mood values fall between 4 and 7, indicating that moderate mood levels are the most common.
# Very low or very high mood values occur less frequently.

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["productivity_score"], bins=20)
plt.title("Productivity Score Distribution")
plt.show()

# %% [markdown]
# The histogram shows the distribution of productivity scores across the dataset.
# Most productivity values fall between 3 and 6, indicating moderate productivity
# levels for most days. Extremely low or extremely high productivity values occur
# less frequently.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm")
plt.title("Feature Correlation")
plt.show()

# %%
features = [
    "TotalSteps",
    "VeryActiveMinutes",
    "FairlyActiveMinutes",
    "LightlyActiveMinutes",
    "SedentaryMinutes",
    "TotalIntensity",
    "sleep_hours",
    "sleep_efficiency",
    "avg_hr",
    "hr_std"
]

X = df[features]

y_mood = df["mood_score"]
y_prod = df["productivity_score"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y_mood, test_size=0.2, random_state=42
)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 0.06979420932908253
# RMSE: 0.13032433295394696

# %%
importance = pd.Series(model.feature_importances_, index=features)

importance.sort_values().plot(kind="barh")
plt.title("Feature Importance")
plt.show()
